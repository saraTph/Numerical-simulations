# %% [markdown]
# # Double structure BEC
#
# We found a double structure BEC for parameters: <br>
# - $\delta/\Omega = 2$
# - $\Omega = 20*\omega_r$ (with $\omega_r=16.9$ Hz and $\omega_r = 26 $ Hz)
# - $n_0=1e11$
# - $a_{11} = a_{22} = a$ and $a_{12} = -a

# %%
wr = 169
Omega = 20*wr
print(Omega)

# %%
from IPython.display import display, Image
fileName = r"C:\Users\Sarah\Documents\GitHub\Numerical-simulations\GPELab\doubleStructureBEC\double structure BEC.png"
display(Image(filename=fileName))
